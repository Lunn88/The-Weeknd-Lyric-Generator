# %% [markdown]
# # Web crawler & Song pre-process

# %%
import os
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %% [markdown]
# # Crawl the song

# %%
songs_url = "https://genius.com/artists/The-weeknd/songs"

driver = webdriver.Chrome()
driver.get(songs_url)

time.sleep(2)

last_height = driver.execute_script("return document.body.scrollHeight")

scroll_offset = 1000
# Scroll for twenty times
for i in range(50):
    driver.execute_script(f"window.scrollTo(0, {last_height - scroll_offset});")
    time.sleep(2)
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        break
    last_height = new_height

page_source = driver.page_source
driver.quit()
print("Finish crawling")
# Out:
# Finish crawling

# %%
soup = BeautifulSoup(page_source, "html.parser")
song_links = []
for link in soup.find_all("a", class_="ListItem__Link-sc-122yj9e-1 klWOzg"):
    href = link.get("href")
    song_links.append(href)
print(len(song_links))
print(song_links[:5])
# Out:
# 780
# ['https://genius.com/The-weeknd-the-hills-lyrics', 'https://genius.com/Lil-uzi-vert-xo-tour-llif3-lyrics', 'https://genius.com/The-weeknd-starboy-lyrics', 'https://genius.com/The-weeknd-cant-feel-my-face-lyrics', 'https://genius.com/The-weeknd-reminder-lyrics']

# %%
links_path = "links.txt"

filtered_links = [link for link in song_links if 'the-weeknd' in link.lower() and 'lyrics' in link.lower()]
print(len(filtered_links))
with open(links_path, 'w', encoding='utf-8') as f:
    for link in filtered_links:
        f.write(link+'\n')
print(filtered_links[:5])
# Out:
# 436
# ['https://genius.com/The-weeknd-the-hills-lyrics', 'https://genius.com/The-weeknd-starboy-lyrics', 'https://genius.com/The-weeknd-cant-feel-my-face-lyrics', 'https://genius.com/The-weeknd-reminder-lyrics', 'https://genius.com/The-weeknd-call-out-my-name-lyrics']

# %%
import re

with open('links.txt', 'r') as file:
    lines = file.read().split('\n')
    links = [line.strip() for line in lines if line.strip()]

for link in links:
    song_title = re.search(r'genius.com/(.*?)-lyrics$', link).group(1).replace('-', ' ')
    song_path = f'Songs/{song_title}.txt'
    
    response = requests.get(link)
    if response.status_code == 200:
        page_content = response.text
        soup = BeautifulSoup(page_content, 'html.parser')
    
        if not os.path.exists('Songs'):
            os.mkdir('Songs')

        # The web use div, class:Lyrics__Container-sc-1ynbvzw-5 Dzxov to contain the lyric.
        # Crawl them all.
        text = ""
        for tag in soup.find_all('div', class_="Lyrics__Container-sc-1ynbvzw-5 Dzxov"):
            text += tag.get_text()
        
        with open(song_path, 'w', encoding='utf-8') as f:
            f.write(text)
        
        print(f"{song_title} has been written into {song_path}.")
    else:
        print("Can\'t visit the page!")
        
print("All lyrics have been written into the song path")
# Out:
# The weeknd the hills has been written into Songs/The weeknd the hills.txt.
# The weeknd starboy has been written into Songs/The weeknd starboy.txt.
# The weeknd cant feel my face has been written into Songs/The weeknd cant feel my face.txt.
# The weeknd reminder has been written into Songs/The weeknd reminder.txt.
# The weeknd call out my name has been written into Songs/The weeknd call out my name.txt.
# The weeknd die for you has been written into Songs/The weeknd die for you.txt.
# The weeknd blinding lights has been written into Songs/The weeknd blinding lights.txt.
# The weeknd often has been written into Songs/The weeknd often.txt.
# The weeknd heartless has been written into Songs/The weeknd heartless.txt.
# The weeknd i feel it coming has been written into Songs/The weeknd i feel it coming.txt.
# The weeknd wicked games has been written into Songs/The weeknd wicked games.txt.
# The weeknd after hours has been written into Songs/The weeknd after hours.txt.
# The weeknd party monster has been written into Songs/The weeknd party monster.txt.
# The weeknd save your tears has been written into Songs/The weeknd save your tears.txt.
# The weeknd earned it has been written into Songs/The weeknd earned it.txt.
# The weeknd sidewalks has been written into Songs/The weeknd sidewalks.txt.
# The weeknd wasted times has been written into Songs/The weeknd wasted times.txt.
# The weeknd tell your friends has been written into Songs/The weeknd tell your friends.txt.
# Kanye west and the weeknd hurricane has been written into Songs/Kanye west and the weeknd hurricane.txt.
# The weeknd montreal has been written into Songs/The weeknd montreal.txt.
# The weeknd the morning has been written into Songs/The weeknd the morning.txt.
# The weeknd king of the fall has been written into Songs/The weeknd king of the fall.txt.
# The weeknd the zone has been written into Songs/The weeknd the zone.txt.
# The weeknd in the night has been written into Songs/The weeknd in the night.txt.
# The weeknd kiss land has been written into Songs/The weeknd kiss land.txt.
# The weeknd and kendrick lamar pray for me has been written into Songs/The weeknd and kendrick lamar pray for me.txt.
# The weeknd acquainted has been written into Songs/The weeknd acquainted.txt.
# The weeknd in your eyes has been written into Songs/The weeknd in your eyes.txt.
# The weeknd house of balloons glass table girls has been written into Songs/The weeknd house of balloons glass table girls.txt.
# The weeknd angel has been written into Songs/The weeknd angel.txt.
# The weeknd try me has been written into Songs/The weeknd try me.txt.
# Juice wrld and the weeknd smile has been written into Songs/Juice wrld and the weeknd smile.txt.
# The weeknd six feet under has been written into Songs/The weeknd six feet under.txt.
# The weeknd faith has been written into Songs/The weeknd faith.txt.
# The weeknd the party and the after party has been written into Songs/The weeknd the party and the after party.txt.
# The weeknd and gesaffelstein i was never there has been written into Songs/The weeknd and gesaffelstein i was never there.txt.
# The weeknd shameless has been written into Songs/The weeknd shameless.txt.
# The weeknd rolling stone has been written into Songs/The weeknd rolling stone.txt.
# The weeknd privilege has been written into Songs/The weeknd privilege.txt.
# The weeknd snowchild has been written into Songs/The weeknd snowchild.txt.
# The weeknd twenty eight has been written into Songs/The weeknd twenty eight.txt.
# The weeknd and gesaffelstein lost in the fire has been written into Songs/The weeknd and gesaffelstein lost in the fire.txt.
# The weeknd escape from la has been written into Songs/The weeknd escape from la.txt.
# The weeknd loft music has been written into Songs/The weeknd loft music.txt.
# The weeknd drunk in love remix has been written into Songs/The weeknd drunk in love remix.txt.
# The weeknd and gesaffelstein hurt you has been written into Songs/The weeknd and gesaffelstein hurt you.txt.
# The weeknd initiation has been written into Songs/The weeknd initiation.txt.
# The weeknd prisoner has been written into Songs/The weeknd prisoner.txt.
# The weeknd true colors has been written into Songs/The weeknd true colors.txt.
# The weeknd false alarm has been written into Songs/The weeknd false alarm.txt.
# The weeknd dark times has been written into Songs/The weeknd dark times.txt.
# The weeknd alone again has been written into Songs/The weeknd alone again.txt.
# The weeknd high for this has been written into Songs/The weeknd high for this.txt.
# The weeknd what you need has been written into Songs/The weeknd what you need.txt.
# The weeknd next has been written into Songs/The weeknd next.txt.
# The weeknd the knowing has been written into Songs/The weeknd the knowing.txt.
# The weeknd the hills eminem remix has been written into Songs/The weeknd the hills eminem remix.txt.
# The weeknd and ariana grande save your tears remix has been written into Songs/The weeknd and ariana grande save your tears remix.txt.
# The weeknd stargirl interlude has been written into Songs/The weeknd stargirl interlude.txt.
# The weeknd real life has been written into Songs/The weeknd real life.txt.
# The weeknd the birds pt 1 has been written into Songs/The weeknd the birds pt 1.txt.
# The weeknd xo the host has been written into Songs/The weeknd xo the host.txt.
# The weeknd secrets has been written into Songs/The weeknd secrets.txt.
# The weeknd valerie has been written into Songs/The weeknd valerie.txt.
# The weeknd echoes of silence has been written into Songs/The weeknd echoes of silence.txt.
# The weeknd hardest to love has been written into Songs/The weeknd hardest to love.txt.
# The weeknd wanderlust has been written into Songs/The weeknd wanderlust.txt.
# The weeknd scared to live has been written into Songs/The weeknd scared to live.txt.
# The weeknd adaptation has been written into Songs/The weeknd adaptation.txt.
# The weeknd the birds pt 2 has been written into Songs/The weeknd the birds pt 2.txt.
# Doja cat and the weeknd you right has been written into Songs/Doja cat and the weeknd you right.txt.
# The weeknd live for has been written into Songs/The weeknd live for.txt.
# The weeknd gone has been written into Songs/The weeknd gone.txt.
# The weeknd too late has been written into Songs/The weeknd too late.txt.
# The weeknd professional has been written into Songs/The weeknd professional.txt.
# Metro boomin the weeknd and 21 savage creepin has been written into Songs/Metro boomin the weeknd and 21 savage creepin.txt.
# Ariana grande and the weeknd love me harder has been written into Songs/Ariana grande and the weeknd love me harder.txt.
# The weeknd lonely star has been written into Songs/The weeknd lonely star.txt.
# The weeknd all i know has been written into Songs/The weeknd all i know.txt.
# The weeknd belong to the world has been written into Songs/The weeknd belong to the world.txt.
# The weeknd ordinary life has been written into Songs/The weeknd ordinary life.txt.
# The weeknd same old song has been written into Songs/The weeknd same old song.txt.
# The weeknd pretty has been written into Songs/The weeknd pretty.txt.
# Ariana grande and the weeknd die for you remix has been written into Songs/Ariana grande and the weeknd die for you remix.txt.
# The weeknd as you are has been written into Songs/The weeknd as you are.txt.
# Ariana grande and the weeknd off the table has been written into Songs/Ariana grande and the weeknd off the table.txt.
# The weeknd enemy has been written into Songs/The weeknd enemy.txt.
# The weeknd love in the sky has been written into Songs/The weeknd love in the sky.txt.
# The weeknd thursday has been written into Songs/The weeknd thursday.txt.
# The weeknd losers has been written into Songs/The weeknd losers.txt.
# The weeknd coming down has been written into Songs/The weeknd coming down.txt.
# The weeknd the fall has been written into Songs/The weeknd the fall.txt.
# The weeknd trust issues remix has been written into Songs/The weeknd trust issues remix.txt.
# The weeknd outside has been written into Songs/The weeknd outside.txt.
# Maluma and the weeknd hawai remix has been written into Songs/Maluma and the weeknd hawai remix.txt.
# The weeknd tears in the rain has been written into Songs/The weeknd tears in the rain.txt.
# Kavinsky odd look the weeknd remix has been written into Songs/Kavinsky odd look the weeknd remix.txt.
# The weeknd nothing without you has been written into Songs/The weeknd nothing without you.txt.
# Swedish house mafia and the weeknd moth to a flame has been written into Songs/Swedish house mafia and the weeknd moth to a flame.txt.
# The weeknd out of time has been written into Songs/The weeknd out of time.txt.
# The weeknd dd has been written into Songs/The weeknd dd.txt.
# The weeknd till dawn here comes the sun has been written into Songs/The weeknd till dawn here comes the sun.txt.
# The weeknd is there someone else has been written into Songs/The weeknd is there someone else.txt.
# The weeknd the town has been written into Songs/The weeknd the town.txt.
# The weeknd gasoline has been written into Songs/The weeknd gasoline.txt.
# The weeknd attention has been written into Songs/The weeknd attention.txt.
# The weeknd less than zero has been written into Songs/The weeknd less than zero.txt.
# The weeknd until i bleed out has been written into Songs/The weeknd until i bleed out.txt.
# The weeknd sacrifice has been written into Songs/The weeknd sacrifice.txt.
# Post malone and the weeknd one right now has been written into Songs/Post malone and the weeknd one right now.txt.
# The weeknd rockin has been written into Songs/The weeknd rockin.txt.
# The weeknd here we go again has been written into Songs/The weeknd here we go again.txt.
# The weeknd material girl has been written into Songs/The weeknd material girl.txt.
# The weeknd take my breath has been written into Songs/The weeknd take my breath.txt.
# The weeknd repeat after me interlude has been written into Songs/The weeknd repeat after me interlude.txt.
# The weeknd a lonely night has been written into Songs/The weeknd a lonely night.txt.
# The weeknd nothing compares has been written into Songs/The weeknd nothing compares.txt.
# The weeknd best friends has been written into Songs/The weeknd best friends.txt.
# The weeknd life of the party has been written into Songs/The weeknd life of the party.txt.
# The weeknd love to lay has been written into Songs/The weeknd love to lay.txt.
# The weeknd how do i make you love me has been written into Songs/The weeknd how do i make you love me.txt.
# Sza the weeknd and travis scott power is power has been written into Songs/Sza the weeknd and travis scott power is power.txt.
# The weeknd the hills nicki minaj remix has been written into Songs/The weeknd the hills nicki minaj remix.txt.
# The weeknd heaven or las vegas has been written into Songs/The weeknd heaven or las vegas.txt.
# The weeknd missed you has been written into Songs/The weeknd missed you.txt.
# The weeknd phantom regret by jim has been written into Songs/The weeknd phantom regret by jim.txt.
# The weeknd dawn fm has been written into Songs/The weeknd dawn fm.txt.
# The weeknd girls born in the 90s has been written into Songs/The weeknd girls born in the 90s.txt.
# The weeknd and madonna popular has been written into Songs/The weeknd and madonna popular.txt.
# The weeknd i heard youre married has been written into Songs/The weeknd i heard youre married.txt.
# The weeknd double fantasy has been written into Songs/The weeknd double fantasy.txt.
# The weeknd starry eyes has been written into Songs/The weeknd starry eyes.txt.
# The weeknd in your eyes remix has been written into Songs/The weeknd in your eyes remix.txt.
# The weeknd dont break my heart has been written into Songs/The weeknd dont break my heart.txt.
# The weeknd birthday suit has been written into Songs/The weeknd birthday suit.txt.
# The weeknd jennie and lily rose depp one of the girls has been written into Songs/The weeknd jennie and lily rose depp one of the girls.txt.
# The weeknd devil may cry has been written into Songs/The weeknd devil may cry.txt.
# Calvin harris and the weeknd over now has been written into Songs/Calvin harris and the weeknd over now.txt.
# The weeknd final lullaby has been written into Songs/The weeknd final lullaby.txt.
# The weeknd every angel is terrifying has been written into Songs/The weeknd every angel is terrifying.txt.
# The weeknd where you belong has been written into Songs/The weeknd where you belong.txt.
# The weeknd a tale by quincy has been written into Songs/The weeknd a tale by quincy.txt.
# The weeknd tell your friends remix has been written into Songs/The weeknd tell your friends remix.txt.
# The weeknd rescue you has been written into Songs/The weeknd rescue you.txt.
# The weeknd take my breath extended version has been written into Songs/The weeknd take my breath extended version.txt.
# The weeknd reminder remix has been written into Songs/The weeknd reminder remix.txt.
# The weeknd love through her has been written into Songs/The weeknd love through her.txt.
# Doja cat and the weeknd you right extended has been written into Songs/Doja cat and the weeknd you right extended.txt.
# The weeknd down low has been written into Songs/The weeknd down low.txt.
# The weeknd let me go has been written into Songs/The weeknd let me go.txt.
# Belly the weeknd and young thug better believe has been written into Songs/Belly the weeknd and young thug better believe.txt.
# Ty dolla sign or nah the weeknd remix has been written into Songs/Ty dolla sign or nah the weeknd remix.txt.
# The weeknd pass dat remix has been written into Songs/The weeknd pass dat remix.txt.
# The weeknd im a virgin has been written into Songs/The weeknd im a virgin.txt.
# The weeknd do it has been written into Songs/The weeknd do it.txt.
# The weeknd appointment has been written into Songs/The weeknd appointment.txt.
# The weeknd the birds interlude has been written into Songs/The weeknd the birds interlude.txt.
# The weeknd our love has been written into Songs/The weeknd our love.txt.
# The weeknd crew love demo has been written into Songs/The weeknd crew love demo.txt.
# The weeknd often remix has been written into Songs/The weeknd often remix.txt.
# The weeknd cure has been written into Songs/The weeknd cure.txt.
# The weeknd out here has been written into Songs/The weeknd out here.txt.
# The weeknd ebony has been written into Songs/The weeknd ebony.txt.
# The weeknd nothing is lost you give me strength has been written into Songs/The weeknd nothing is lost you give me strength.txt.
# The weeknd sorry one night stand has been written into Songs/The weeknd sorry one night stand.txt.
# Belly and the weeknd die for it has been written into Songs/Belly and the weeknd die for it.txt.
# The weeknd and rosalia blinding lights remix has been written into Songs/The weeknd and rosalia blinding lights remix.txt.
# The weeknd superhero has been written into Songs/The weeknd superhero.txt.
# The weeknd patient has been written into Songs/The weeknd patient.txt.
# The weeknd take me back has been written into Songs/The weeknd take me back.txt.
# The weeknd lily rose depp and ramsey fill the void has been written into Songs/The weeknd lily rose depp and ramsey fill the void.txt.
# The weeknd a lesser man has been written into Songs/The weeknd a lesser man.txt.
# The weeknd lil baby and suzanna son false idols has been written into Songs/The weeknd lil baby and suzanna son false idols.txt.
# The weeknd lonely thoughts has been written into Songs/The weeknd lonely thoughts.txt.
# The weeknd often kygo remix has been written into Songs/The weeknd often kygo remix.txt.
# The weeknd x ray has been written into Songs/The weeknd x ray.txt.
# The weeknd and suzanna son family has been written into Songs/The weeknd and suzanna son family.txt.
# The weeknd all day love numb has been written into Songs/The weeknd all day love numb.txt.
# The weeknd its ending has been written into Songs/The weeknd its ending.txt.
# The weeknd baddest bitch around has been written into Songs/The weeknd baddest bitch around.txt.
# The weeknd heartless vapor wave remix has been written into Songs/The weeknd heartless vapor wave remix.txt.
# The weeknd quatre neuf has been written into Songs/The weeknd quatre neuf.txt.
# The weeknd jealous guy has been written into Songs/The weeknd jealous guy.txt.
# The weeknd party has been written into Songs/The weeknd party.txt.
# The weeknd king of the fall remix has been written into Songs/The weeknd king of the fall remix.txt.
# The weeknd odd look has been written into Songs/The weeknd odd look.txt.
# The weeknd insomnia has been written into Songs/The weeknd insomnia.txt.
# The weeknd another one of me og has been written into Songs/The weeknd another one of me og.txt.
# The weeknd i wanna feel you has been written into Songs/The weeknd i wanna feel you.txt.
# The weeknd heartless remix has been written into Songs/The weeknd heartless remix.txt.
# The weeknd die for you sza remix has been written into Songs/The weeknd die for you sza remix.txt.
# The weeknd take me back to la myself has been written into Songs/The weeknd take me back to la myself.txt.
# The weeknd where do i go has been written into Songs/The weeknd where do i go.txt.
# The weeknd wanderlust pharrell remix has been written into Songs/The weeknd wanderlust pharrell remix.txt.
# Sabrina claudio and the weeknd christmas blues has been written into Songs/Sabrina claudio and the weeknd christmas blues.txt.
# The weeknd wanna see has been written into Songs/The weeknd wanna see.txt.
# Metro boomin the weeknd and diddy creepin remix has been written into Songs/Metro boomin the weeknd and diddy creepin remix.txt.
# The weeknd get in there has been written into Songs/The weeknd get in there.txt.
# The weeknd be god has been written into Songs/The weeknd be god.txt.
# The weeknd like a god has been written into Songs/The weeknd like a god.txt.
# The weeknd 6 inch heel has been written into Songs/The weeknd 6 inch heel.txt.
# The weeknd for your eyes only has been written into Songs/The weeknd for your eyes only.txt.
# The weeknd and summer walker best friends remix has been written into Songs/The weeknd and summer walker best friends remix.txt.
# The weeknd when i pullin up demo has been written into Songs/The weeknd when i pullin up demo.txt.
# The weeknd for the first time has been written into Songs/The weeknd for the first time.txt.
# The weeknd blinding lights chromatics remix has been written into Songs/The weeknd blinding lights chromatics remix.txt.
# The weeknd half measure has been written into Songs/The weeknd half measure.txt.
# The weeknd down low freestyle has been written into Songs/The weeknd down low freestyle.txt.
# The weeknd all that money 6 inch demo has been written into Songs/The weeknd all that money 6 inch demo.txt.
# The weeknd heavenly creatures has been written into Songs/The weeknd heavenly creatures.txt.
# The weeknd how will i know has been written into Songs/The weeknd how will i know.txt.
# The weeknd woo demo has been written into Songs/The weeknd woo demo.txt.
# The weeknd starboy kygo remix has been written into Songs/The weeknd starboy kygo remix.txt.
# The weeknd win my love has been written into Songs/The weeknd win my love.txt.
# The weeknd i love it when youre angry has been written into Songs/The weeknd i love it when youre angry.txt.
# The weeknd the source has been written into Songs/The weeknd the source.txt.
# The weeknd one right now demo has been written into Songs/The weeknd one right now demo.txt.
# The weeknd on top has been written into Songs/The weeknd on top.txt.
# The weeknd airports has been written into Songs/The weeknd airports.txt.
# The weeknd in vein remix has been written into Songs/The weeknd in vein remix.txt.
# The weeknd the warning birds interlude has been written into Songs/The weeknd the warning birds interlude.txt.
# The weeknd i dont need love has been written into Songs/The weeknd i dont need love.txt.
# The weeknd untitled 2015 gone has been written into Songs/The weeknd untitled 2015 gone.txt.
# The weeknd untitled has been written into Songs/The weeknd untitled.txt.
# The weeknd gone tell your friends demo has been written into Songs/The weeknd gone tell your friends demo.txt.
# The weeknd wow has been written into Songs/The weeknd wow.txt.
# The weeknd come thru has been written into Songs/The weeknd come thru.txt.
# The weeknd try me remix has been written into Songs/The weeknd try me remix.txt.
# The weeknd hold your heart demo has been written into Songs/The weeknd hold your heart demo.txt.
# The weeknd all i know remix has been written into Songs/The weeknd all i know remix.txt.
# The weeknd might not make it open verses demo has been written into Songs/The weeknd might not make it open verses demo.txt.
# The weeknd already time under the sun has been written into Songs/The weeknd already time under the sun.txt.
# The weeknd youngest killer has been written into Songs/The weeknd youngest killer.txt.
# The weeknd serve this royalty has been written into Songs/The weeknd serve this royalty.txt.
# The weeknd red eye has been written into Songs/The weeknd red eye.txt.
# The weeknd repeat after me has been written into Songs/The weeknd repeat after me.txt.
# The weeknd pure life has been written into Songs/The weeknd pure life.txt.
# The weeknd motionless has been written into Songs/The weeknd motionless.txt.
# The weeknd heavy heart has been written into Songs/The weeknd heavy heart.txt.
# The weeknd after hours the blaze remix has been written into Songs/The weeknd after hours the blaze remix.txt.
# The weeknd angel face has been written into Songs/The weeknd angel face.txt.
# The weeknd beautiful desires has been written into Songs/The weeknd beautiful desires.txt.
# The weeknd and mike dean the lure main theme has been written into Songs/The weeknd and mike dean the lure main theme.txt.
# The weeknd not used to the town demo has been written into Songs/The weeknd not used to the town demo.txt.
# The weeknd call out my name a cappella has been written into Songs/The weeknd call out my name a cappella.txt.
# The weeknd the delay has been written into Songs/The weeknd the delay.txt.
# The weeknd to my fans oct 4 has been written into Songs/The weeknd to my fans oct 4.txt.
# The weeknd whisperers xo demo has been written into Songs/The weeknd whisperers xo demo.txt.
# The weeknd insomnia 2 has been written into Songs/The weeknd insomnia 2.txt.
# The weeknd six feet under original version has been written into Songs/The weeknd six feet under original version.txt.
# The weeknd love to lay leak has been written into Songs/The weeknd love to lay leak.txt.
# The weeknd save your tears opn remix has been written into Songs/The weeknd save your tears opn remix.txt.
# The weeknd privilege remix has been written into Songs/The weeknd privilege remix.txt.
# The weeknd tell your friends met gala remix has been written into Songs/The weeknd tell your friends met gala remix.txt.
# The weeknd cant feel my face martin garrix remix has been written into Songs/The weeknd cant feel my face martin garrix remix.txt.
# The weeknd crazy sexy has been written into Songs/The weeknd crazy sexy.txt.
# The weeknd save your tears demo has been written into Songs/The weeknd save your tears demo.txt.
# The weeknd yeah has been written into Songs/The weeknd yeah.txt.
# The weeknd often demo has been written into Songs/The weeknd often demo.txt.
# The weeknd heavenly creatures demo has been written into Songs/The weeknd heavenly creatures demo.txt.
# Swedish house mafia and the weeknd sacrifice remix has been written into Songs/Swedish house mafia and the weeknd sacrifice remix.txt.
# The weeknd nothing without you demo has been written into Songs/The weeknd nothing without you demo.txt.
# The weeknd in your eyes kenny g remix has been written into Songs/The weeknd in your eyes kenny g remix.txt.
# The weeknd seventeen has been written into Songs/The weeknd seventeen.txt.
# The weeknd cut you until i bleed out demo has been written into Songs/The weeknd cut you until i bleed out demo.txt.
# Florence the machine shake it out the weeknd remix has been written into Songs/Florence the machine shake it out the weeknd remix.txt.
# The weeknd scared to live snl live has been written into Songs/The weeknd scared to live snl live.txt.
# The weeknd widow has been written into Songs/The weeknd widow.txt.
# The weeknd practice demo has been written into Songs/The weeknd practice demo.txt.
# The weeknd the morning og has been written into Songs/The weeknd the morning og.txt.
# The weeknd mirrors has been written into Songs/The weeknd mirrors.txt.
# The weeknd xo demo has been written into Songs/The weeknd xo demo.txt.
# The weeknd in my life has been written into Songs/The weeknd in my life.txt.
# The weeknd loneliness has been written into Songs/The weeknd loneliness.txt.
# The weeknd mood music part two prisoner has been written into Songs/The weeknd mood music part two prisoner.txt.
# The weeknd heartless radio edit has been written into Songs/The weeknd heartless radio edit.txt.
# The weeknd heartbreak devil has been written into Songs/The weeknd heartbreak devil.txt.
# The weeknd loft music og has been written into Songs/The weeknd loft music og.txt.
# The weeknd never go home alone again demo has been written into Songs/The weeknd never go home alone again demo.txt.
# The weeknd the weeknd music videos has been written into Songs/The weeknd the weeknd music videos.txt.
# The weeknd take my breath remix has been written into Songs/The weeknd take my breath remix.txt.
# The weeknd old news has been written into Songs/The weeknd old news.txt.
# The weeknd ynp has been written into Songs/The weeknd ynp.txt.
# The weeknd one of those nights demo has been written into Songs/The weeknd one of those nights demo.txt.
# The weeknd keep it on that xo interlude has been written into Songs/The weeknd keep it on that xo interlude.txt.
# The weeknd tongue has been written into Songs/The weeknd tongue.txt.
# The weeknd can we get high has been written into Songs/The weeknd can we get high.txt.
# The weeknd blinding lights major lazer remix has been written into Songs/The weeknd blinding lights major lazer remix.txt.
# The weeknd and ariana grande die for you remix acapella has been written into Songs/The weeknd and ariana grande die for you remix acapella.txt.
# The weeknd glass table girls demo has been written into Songs/The weeknd glass table girls demo.txt.
# The weeknd attention demo has been written into Songs/The weeknd attention demo.txt.
# The weeknd impress you dirty south has been written into Songs/The weeknd impress you dirty south.txt.
# Swedish house mafia and the weeknd moth to a flame extended mix has been written into Songs/Swedish house mafia and the weeknd moth to a flame extended mix.txt.
# Lady gaga marry the night the weeknd and illangelo remix has been written into Songs/Lady gaga marry the night the weeknd and illangelo remix.txt.
# The weeknd and kaytranada out of time kaytranada remix has been written into Songs/The weeknd and kaytranada out of time kaytranada remix.txt.
# The weeknd tempo slow has been written into Songs/The weeknd tempo slow.txt.
# The weeknd after hours til dawn tour setlist has been written into Songs/The weeknd after hours til dawn tour setlist.txt.
# The weeknd starry eyes mike dean remix has been written into Songs/The weeknd starry eyes mike dean remix.txt.
# The weeknd starboy vicetone remix has been written into Songs/The weeknd starboy vicetone remix.txt.
# The weeknd or nah live has been written into Songs/The weeknd or nah live.txt.
# The weeknd alone again instagram demo has been written into Songs/The weeknd alone again instagram demo.txt.
# Xxxtentacion whoa mind in awe the weeknd remix has been written into Songs/Xxxtentacion whoa mind in awe the weeknd remix.txt.
# Ariana grande and the weeknd love me harder gryffin remix has been written into Songs/Ariana grande and the weeknd love me harder gryffin remix.txt.
# The weeknd nothing without you original has been written into Songs/The weeknd nothing without you original.txt.
# The weeknd double fantasy radio edit has been written into Songs/The weeknd double fantasy radio edit.txt.
# The weeknd my darkest hours after hours prince 85 remix has been written into Songs/The weeknd my darkest hours after hours prince 85 remix.txt.
# Cody simpson what you want the weeknd re imagination has been written into Songs/Cody simpson what you want the weeknd re imagination.txt.
# The weeknd prisoner tomsize remix has been written into Songs/The weeknd prisoner tomsize remix.txt.
# Metro boomin the weeknd and 21 savage creepin choppednotslopped has been written into Songs/Metro boomin the weeknd and 21 savage creepin choppednotslopped.txt.
# The weeknd die for you live has been written into Songs/The weeknd die for you live.txt.
# The weeknd low life live has been written into Songs/The weeknd low life live.txt.
# Swedish house mafia and the weeknd moth to a flame moojo remix has been written into Songs/Swedish house mafia and the weeknd moth to a flame moojo remix.txt.
# The weeknd blinding lights acapella has been written into Songs/The weeknd blinding lights acapella.txt.
# The weeknd after hours live has been written into Songs/The weeknd after hours live.txt.
# The weeknd limbo the host demo has been written into Songs/The weeknd limbo the host demo.txt.
# The weeknd blinding lights instrumental has been written into Songs/The weeknd blinding lights instrumental.txt.
# The weeknd shut up kid has been written into Songs/The weeknd shut up kid.txt.
# The weeknd why feel bad has been written into Songs/The weeknd why feel bad.txt.
# Lorde royals the weeknd remix has been written into Songs/Lorde royals the weeknd remix.txt.
# The weeknd is there someone else live has been written into Songs/The weeknd is there someone else live.txt.
# The weeknd starboy c418 remix has been written into Songs/The weeknd starboy c418 remix.txt.
# The weeknd what you need unreleased has been written into Songs/The weeknd what you need unreleased.txt.
# The weeknd the fall demo has been written into Songs/The weeknd the fall demo.txt.
# The weeknd dawn fm opn remix has been written into Songs/The weeknd dawn fm opn remix.txt.
# The weeknd alone again live has been written into Songs/The weeknd alone again live.txt.
# The weeknd take you the noise era has been written into Songs/The weeknd take you the noise era.txt.
# Swedish house mafia the weeknd and chris lake moth to a flame chris lake remix has been written into Songs/Swedish house mafia the weeknd and chris lake moth to a flame chris lake remix.txt.
# The weeknd save your tears live has been written into Songs/The weeknd save your tears live.txt.
# The weeknd hurricane live has been written into Songs/The weeknd hurricane live.txt.
# The weeknd take my breath instrumental has been written into Songs/The weeknd take my breath instrumental.txt.
# Travis scott bad bunny and the weeknd k pop chopped and screwed has been written into Songs/Travis scott bad bunny and the weeknd k pop chopped and screwed.txt.
# The weeknd crew love solo demo has been written into Songs/The weeknd crew love solo demo.txt.
# The weeknd blinding lights live has been written into Songs/The weeknd blinding lights live.txt.
# The weeknd king of the fall demo has been written into Songs/The weeknd king of the fall demo.txt.
# The weeknd the hills emo g remix has been written into Songs/The weeknd the hills emo g remix.txt.
# The weeknd how do i make you love me sebastian ingrosso and salvatore ganacci remix has been written into Songs/The weeknd how do i make you love me sebastian ingrosso and salvatore ganacci remix.txt.
# The weeknd here we go again demo has been written into Songs/The weeknd here we go again demo.txt.
# The weeknd call out my name live has been written into Songs/The weeknd call out my name live.txt.
# The weeknd intro live has been written into Songs/The weeknd intro live.txt.
# The weeknd party monster live has been written into Songs/The weeknd party monster live.txt.
# The weeknd sacrifice live has been written into Songs/The weeknd sacrifice live.txt.
# The weeknd the zone video version has been written into Songs/The weeknd the zone video version.txt.
# The weeknd starboy live has been written into Songs/The weeknd starboy live.txt.
# The weeknd i was never there live has been written into Songs/The weeknd i was never there live.txt.
# The weeknd wicked games live has been written into Songs/The weeknd wicked games live.txt.
# The weeknd often live has been written into Songs/The weeknd often live.txt.
# The weeknd stargirl interlude extended has been written into Songs/The weeknd stargirl interlude extended.txt.
# The weeknd die for you sped up has been written into Songs/The weeknd die for you sped up.txt.
# The weeknd gasoline live has been written into Songs/The weeknd gasoline live.txt.
# The weeknd nothing compares nightcore remix has been written into Songs/The weeknd nothing compares nightcore remix.txt.
# The weeknd crew love live has been written into Songs/The weeknd crew love live.txt.
# The weeknd the hills live has been written into Songs/The weeknd the hills live.txt.
# The weeknd outro live has been written into Songs/The weeknd outro live.txt.
# The weeknd how do i make you love me live has been written into Songs/The weeknd how do i make you love me live.txt.
# The weeknd often dj soltrix erotic bachata remix has been written into Songs/The weeknd often dj soltrix erotic bachata remix.txt.
# The weeknd faith live has been written into Songs/The weeknd faith live.txt.
# The weeknd kiss land live has been written into Songs/The weeknd kiss land live.txt.
# The weeknd i feel it coming live has been written into Songs/The weeknd i feel it coming live.txt.
# The weeknd the morning live has been written into Songs/The weeknd the morning live.txt.
# The weeknd out of time live has been written into Songs/The weeknd out of time live.txt.
# The weeknd less than zero live has been written into Songs/The weeknd less than zero live.txt.
# The weeknd take my breath live has been written into Songs/The weeknd take my breath live.txt.
# The weeknd earned it fifty shades of grey marian hill remix has been written into Songs/The weeknd earned it fifty shades of grey marian hill remix.txt.
# The weeknd die for you mixed has been written into Songs/The weeknd die for you mixed.txt.
# The weeknd cant feel my face live has been written into Songs/The weeknd cant feel my face live.txt.
# The weeknd heartless live has been written into Songs/The weeknd heartless live.txt.
# The weeknd witches and panthers for love snippet has been written into Songs/The weeknd witches and panthers for love snippet.txt.
# The weeknd take my hand has been written into Songs/The weeknd take my hand.txt.
# Ariana grande and the weeknd love me harder alex ghenea remix has been written into Songs/Ariana grande and the weeknd love me harder alex ghenea remix.txt.
# Carneyval the weeknd and halsey id2 from todays hits november 2022 cant feel my face bad at love mixed has been written into Songs/Carneyval the weeknd and halsey id2 from todays hits november 2022 cant feel my face bad at love mixed.txt.
# The weeknd die for you instrumental has been written into Songs/The weeknd die for you instrumental.txt.
# Swedish house mafia and the weeknd moth to a flame tourist remix has been written into Songs/Swedish house mafia and the weeknd moth to a flame tourist remix.txt.
# The weeknd danny boy styles october has been written into Songs/The weeknd danny boy styles october.txt.
# The weeknd and kaytranada out of time kaytranada remix radio edit has been written into Songs/The weeknd and kaytranada out of time kaytranada remix radio edit.txt.
# The weeknd wanderlust clean bandit remix has been written into Songs/The weeknd wanderlust clean bandit remix.txt.
# The weeknd who you are has been written into Songs/The weeknd who you are.txt.
# The weeknd wanderlust steve pitron and max sanna club mix has been written into Songs/The weeknd wanderlust steve pitron and max sanna club mix.txt.
# The weeknd nothing without you v2 has been written into Songs/The weeknd nothing without you v2.txt.
# Bootstraps earned it the weeknd cover has been written into Songs/Bootstraps earned it the weeknd cover.txt.
# The weeknd hold your heart squad has been written into Songs/The weeknd hold your heart squad.txt.
# The weeknd hurt you demo has been written into Songs/The weeknd hurt you demo.txt.
# The weeknd out of time instrumental has been written into Songs/The weeknd out of time instrumental.txt.
# Travis scott bad bunny and the weeknd k pop instrumental has been written into Songs/Travis scott bad bunny and the weeknd k pop instrumental.txt.
# The weeknd the hills rl grime remix has been written into Songs/The weeknd the hills rl grime remix.txt.
# Travis scott bad bunny and the weeknd k pop sped up has been written into Songs/Travis scott bad bunny and the weeknd k pop sped up.txt.
# The weeknd love in the sky demo has been written into Songs/The weeknd love in the sky demo.txt.
# The weeknd save your tears vicetone remix has been written into Songs/The weeknd save your tears vicetone remix.txt.
# The weeknd in the mood has been written into Songs/The weeknd in the mood.txt.
# Ariana grande off the table ft the weeknd vevo official live performance has been written into Songs/Ariana grande off the table ft the weeknd vevo official live performance.txt.
# The weeknd wanderlust steve pitron and max sanna radio edit has been written into Songs/The weeknd wanderlust steve pitron and max sanna radio edit.txt.
# Beyonce post malone the weeknd and gesaffelstein break my soul wow lost in the fire mixed has been written into Songs/Beyonce post malone the weeknd and gesaffelstein break my soul wow lost in the fire mixed.txt.
# The weeknd is there someone else from the after hours til dawn live album has been written into Songs/The weeknd is there someone else from the after hours til dawn live album.txt.
# The weeknd shot for me reference has been written into Songs/The weeknd shot for me reference.txt.
# The weeknd invisible has been written into Songs/The weeknd invisible.txt.
# The weeknd when the grip hits has been written into Songs/The weeknd when the grip hits.txt.
# The weeknd dream to belong has been written into Songs/The weeknd dream to belong.txt.
# The weeknd blinding lights demo has been written into Songs/The weeknd blinding lights demo.txt.
# The weeknd untitled instrumental has been written into Songs/The weeknd untitled instrumental.txt.
# The weeknd double fantasy mixed has been written into Songs/The weeknd double fantasy mixed.txt.
# The weeknd where you belong sohn remix has been written into Songs/The weeknd where you belong sohn remix.txt.
# The weeknd and madonna popular mixed has been written into Songs/The weeknd and madonna popular mixed.txt.
# The weeknd die for you telykast remix has been written into Songs/The weeknd die for you telykast remix.txt.
# The weeknd after life has been written into Songs/The weeknd after life.txt.
# Kendrick lamar doja cat and the weeknd poetic justice you right mixed has been written into Songs/Kendrick lamar doja cat and the weeknd poetic justice you right mixed.txt.
# The weeknd i like that has been written into Songs/The weeknd i like that.txt.
# The weeknd dream v2 has been written into Songs/The weeknd dream v2.txt.
# The weeknd the hills dimitri vegas and like mike remix has been written into Songs/The weeknd the hills dimitri vegas and like mike remix.txt.
# The weeknd blinding lights w w festival mix has been written into Songs/The weeknd blinding lights w w festival mix.txt.
# Kali uchis and the weeknd no hay ley take my breath mixed has been written into Songs/Kali uchis and the weeknd no hay ley take my breath mixed.txt.
# The weeknd save your tears live at the brit awards 2021 has been written into Songs/The weeknd save your tears live at the brit awards 2021.txt.
# The weeknd die for you mixed dec 2022 has been written into Songs/The weeknd die for you mixed dec 2022.txt.
# Swedish house mafia and the weeknd moth to a flame kaaze arena mix has been written into Songs/Swedish house mafia and the weeknd moth to a flame kaaze arena mix.txt.
# Metro boomin the weeknd and 21 savage creepin vandal on da track edit mixed has been written into Songs/Metro boomin the weeknd and 21 savage creepin vandal on da track edit mixed.txt.
# The weeknd starboy radio edit has been written into Songs/The weeknd starboy radio edit.txt.
# The weeknd gasoline aistriuchan gaeilge has been written into Songs/The weeknd gasoline aistriuchan gaeilge.txt.
# Genius korean translations the weeknd dawn fm has been written into Songs/Genius korean translations the weeknd dawn fm.txt.
# Genius korean translations the weeknd out of time has been written into Songs/Genius korean translations the weeknd out of time.txt.
# Domiziana and the weeknd ohne benzin tiesto remix cant feel my face mixed has been written into Songs/Domiziana and the weeknd ohne benzin tiesto remix cant feel my face mixed.txt.
# The weeknd die for you armentani brothers and jakked remix mixed has been written into Songs/The weeknd die for you armentani brothers and jakked remix mixed.txt.
# The weeknd too late original has been written into Songs/The weeknd too late original.txt.
# The weeknd blinding lights mixed has been written into Songs/The weeknd blinding lights mixed.txt.
# The weeknd starboy cesky preklad has been written into Songs/The weeknd starboy cesky preklad.txt.
# Genius korean translations the weeknd gasoline has been written into Songs/Genius korean translations the weeknd gasoline.txt.
# Skrillex bobby raps metro boomin the weeknd and 21 savage creepin leave me like this wesh edit mixed has been written into Songs/Skrillex bobby raps metro boomin the weeknd and 21 savage creepin leave me like this wesh edit mixed.txt.
# Genius korean translations the weeknd less than zero has been written into Songs/Genius korean translations the weeknd less than zero.txt.
# Genius korean translations the weeknd take my breath has been written into Songs/Genius korean translations the weeknd take my breath.txt.
# Genius russian translations the weeknd alone again live has been written into Songs/Genius russian translations the weeknd alone again live.txt.
# Genius korean translations the weeknd here we go again has been written into Songs/Genius korean translations the weeknd here we go again.txt.
# Genius korean translations the weeknd how do i make you love me has been written into Songs/Genius korean translations the weeknd how do i make you love me.txt.
# The weeknd ok event 6507 has been written into Songs/The weeknd ok event 6507.txt.
# Genius korean translations the weeknd is there someone else has been written into Songs/Genius korean translations the weeknd is there someone else.txt.
# Genius korean translations the weeknd starry eyes has been written into Songs/Genius korean translations the weeknd starry eyes.txt.
# Genius korean translations the weeknd dont break my heart has been written into Songs/Genius korean translations the weeknd dont break my heart.txt.
# Genius korean translations the weeknd i heard youre married has been written into Songs/Genius korean translations the weeknd i heard youre married.txt.
# Genius korean translations the weeknd best friends has been written into Songs/Genius korean translations the weeknd best friends.txt.
# Genius korean translations the weeknd sacrifice has been written into Songs/Genius korean translations the weeknd sacrifice.txt.
# All lyrics have been written into the song path

# %%
def clean_lyrics(input_text):
    output_text = ""
    i = 0
    while i < len(input_text):
        if input_text[i] not in ['\"','\'', '(', ')', '.', '…', ';', '—']:
            output_text += input_text[i]
        i += 1

    return output_text

# %%
def insert_newlines(input_text):
    output_text = ""
    i = 0
    skip = 0

    while i < len(input_text):
        current_char = input_text[i]
        
        # The song text contains tags like [intro], [verse].
        # We don't want that, so skip them.
        if current_char == '[':
            skip = 1
            i += 1
            continue
        elif current_char == ']':
            skip = 0
            i += 1
            continue
        if skip == 1:
            i += 1
            continue
            
        else:
            # Insert newlines base on whether the character is upper or not.
            if current_char.isupper():
                if input_text[i - 1] in [' ', '-']:
                    output_text += current_char
                    i += 1
                    continue
                else:
                    output_text += '\n' + current_char
                    i += 1
                    continue

            output_text += current_char
            i += 1

    return output_text

# %%
def merge_short_lines(input_text):
    lines = input_text.split('\n')
    merged_lines = []
    current_line = ""

    for line in lines:
        if len(line.split(' ')) <= 2:
            current_line += " " + line
        else:
            if current_line and len(merged_lines) > 0:
                merged_lines[-1] += current_line
                current_line = ""
            merged_lines.append(line)
            
    # for the last line
    if current_line:
        merged_lines[-1] += current_line

    merged_text = '\n'.join(merged_lines)
    return merged_text

# %% [markdown]
# # Write all lyrics into one file

# %%
folder_path = 'Songs'
file_list = os.listdir(folder_path)

content = ""
for file_name in file_list:
    file_path = os.path.join(folder_path, file_name)
    with open(file_path, 'r', encoding='utf-8') as f:
        content += f.read() + '\n'

content = clean_lyrics(content)
content = insert_newlines(content)
content = merge_short_lines(content)

lyric_path = "The Weeknd.txt"
with open(lyric_path, 'w', encoding='utf-8') as f:
    f.write(content)
    
print("Wrote all the lyrics into " + lyric_path)
# Out:
# Wrote all the lyrics into The Weeknd.txt
